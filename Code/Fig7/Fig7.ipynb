% %% [markdown]
% # Fig 7

% %%
%This code is to generate Fig 7 in the paper. The used data for this figure has been stored in the Data/Fig7 folder.

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-1040sswithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-101smwithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-102smwithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-1540sswithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-151smwithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-152smwithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-2040sswithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-201smwithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);

% %%
load /Users/mesmaeili/Downloads/data-2016-09-22-202smwithxypos;
x=x.';
y=y.';
y=double(y);
%z=[x,y];
hist3([x,y],'CDataMode','auto','FaceColor','interp', 'LineWidth',1);

ax = gca;
ax.YAxis.FontSize = 10; 
ax.XAxis.FontSize = 10; 
ax.ZAxis.FontSize = 10; 
xlabel('Distance (m)', 'fontsize',10);
ylabel('Time Seen Together (s)','fontsize', 10);
zlabel('Contact Occurrences (log scale)','fontsize', 10);
title('To = 20 s, Tcp = 120 s', 'fontsize', 10);
S = findobj('type','surf');
ZD = get(S,'zdata');
ZD(~ZD) = .1;
set(S,'zdata',ZD);
set(gca, 'ZScale', 'log');
set(gca, 'LineWidth', 2);
