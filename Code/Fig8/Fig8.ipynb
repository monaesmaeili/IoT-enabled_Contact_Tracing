% %% [markdown]
% # Fig 8

% %%
% This code is to generate Fig 8 in the paper. The used data for this figure has been stored in the Data/Fig8 folder.

% %%
clear all;
load /Users/mesmaeili/Downloads/week2229-151sm-y;
h=histogram(y, 'EdgeColor', 'black', 'LineWidth', 0.5);
fig.Renderer = 'painters';
ax = gca;
ax.YAxis.FontSize = 10; 

ax.XAxis.FontSize = 10; 

ax.XGrid = 'off';
ax.YGrid = 'on';
ax.GridAlpha = 1;

xlabel('Time Seen Together (s)', 'fontsize', 10);
ylabel('Contact Occurrences (log scale)', 'fontsize', 10);
title('To = 15 s, Tcp = 1 minute', 'fontsize', 15);
S = findobj('type','surf');
YD = get(S,'ydata');
YD(~YD) = .1;
set(S,'ydata',YD);
set(gca, 'YScale', 'log');
set(gca, 'LineWidth', 2);




hold on;
figure;

load /Users/mesmaeili/Downloads/week2229-151sm-x;
h=histogram(x, 'EdgeColor', 'black', 'LineWidth', 0.5);
ax = gca;
ax.YAxis.FontSize = 10; 

ax.XAxis.FontSize = 10; 

ax.XGrid = 'off';
ax.YGrid = 'on';
ax.GridAlpha = 1;

xlabel('Distance (m)', 'fontsize', 10);
ylabel('Contact Occurrences', 'fontsize', 10);
title('To = 15 s, Tcp = 1 minute', 'fontsize', 15);
